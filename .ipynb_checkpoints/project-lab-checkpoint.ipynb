# %% [markdown]
# # SPX Volatility Term Structure Analysis

# %% [markdown]
# Click [here](https://github.com/jackliu234/spx-vol-term-struct/blob/master/project.ipynb) to download this notebook.

# %% [markdown]
# ## Section 1: Packages

# %% [markdown]
# Import all relevant packages.

# %%
import sys
import json
import quandl
import functools
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from urllib.request import urlopen
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## Section 2: Function

# %% [markdown]
# Define functions.

# %%
def yahoo_parser(url):
    response = urlopen(url)
    data = json.loads(response.read().decode("utf-8"))['chart']['result'][0]
    t = pd.to_datetime(data['timestamp'], unit='s').date
    c = data['indicators']['quote'][0]['close']
    return pd.DataFrame({'close': c}, index=t)


def default_parser(url):
    return pd.read_csv(url, index_col=0, parse_dates=True)


def retrieve(source, code, label, column=None):
    query = {
        'yahoo': 'https://query1.finance.yahoo.com/v8/finance/chart/{}?period1=0&period2=5000000000&interval=1d',
    }
    parser = {
        'yahoo': yahoo_parser,
    }
    url = query.get(source).format(code)
    df = parser.get(source, default_parser)(url)
    df.index.name = None
    df.columns = [col.lower() for col in df.columns] if df.shape[1] > 1 else [label]
    if not column: column = df.columns
    all_dates = pd.date_range(df.index.min(), df.index.max(), freq='D')
    df = df.replace('.', None).reindex(all_dates).fillna(method='ffill')
    return df.astype('float')[column].squeeze()

# %% [markdown]
# ## Section 3: Data

# %%
# Load yahoo data
df = retrieve('yahoo', '^GSPC', 'SPX').to_frame()

# %%
# remove all weekends
df = df.reindex(pd.date_range(start="1970-01-02", end="2018-12-31", freq='B'))

# take the log price and return
df['log_SPX'] = np.log(df["SPX"])
df['r'] = df['log_SPX'] - df['log_SPX'].shift(1)
df['r_ann'] = df['r'] * 260

# calculate rolling volatilities
df["vol_1w"] = df["r"].rolling(5).std() * np.sqrt(260)
df["vol_1m"] = df["r"].rolling(22).std() * np.sqrt(260)
df["vol_6m"] = df["r"].rolling(130).std() * np.sqrt(260)
df["vol_1y"] = df["r"].rolling(260).std() * np.sqrt(260)
df["vol_2y"] = df["r"].rolling(520).std() * np.sqrt(260)

# remove na
df.fillna(value=0, inplace=True)

# %%
df.head(10)
# Out:
#                   SPX   log_SPX         r     r_ann    vol_1w  vol_1m  vol_6m  \
# 1970-01-02  93.000000  4.532599  0.000000  0.000000  0.000000     0.0     0.0
# 1970-01-05  93.459999  4.537534  0.004934  1.282849  0.000000     0.0     0.0
# 1970-01-06  92.820000  4.530662 -0.006871 -1.786563  0.000000     0.0     0.0
# 1970-01-07  92.629997  4.528613 -0.002049 -0.532765  0.000000     0.0     0.0
# 1970-01-08  92.680000  4.529153  0.000540  0.140314  0.000000     0.0     0.0
# 1970-01-09  92.400002  4.526127 -0.003026 -0.786684  0.070667     0.0     0.0
# 1970-01-12  91.699997  4.518522 -0.007605 -1.977209  0.054922     0.0     0.0
# 1970-01-13  91.919998  4.520919  0.002396  0.623030  0.061522     0.0     0.0
# 1970-01-14  91.650002  4.517977 -0.002942 -0.764822  0.061952     0.0     0.0
# 1970-01-15  91.680000  4.518304  0.000327  0.085089  0.061374     0.0     0.0
#
#             vol_1y  vol_2y
# 1970-01-02     0.0     0.0
# 1970-01-05     0.0     0.0
# 1970-01-06     0.0     0.0
# 1970-01-07     0.0     0.0
# 1970-01-08     0.0     0.0
# 1970-01-09     0.0     0.0
# 1970-01-12     0.0     0.0
# 1970-01-13     0.0     0.0
# 1970-01-14     0.0     0.0
# 1970-01-15     0.0     0.0

# %%
df.tail(10)
# Out:
#                     SPX   log_SPX         r      r_ann    vol_1w    vol_1m  \
# 2018-12-18  2546.159912  7.842342  0.000086   0.022463  0.196941  0.218995
# 2018-12-19  2506.959961  7.826826 -0.015515  -4.034019  0.166801  0.218068
# 2018-12-20  2467.419922  7.810928 -0.015898  -4.133430  0.135027  0.216143
# 2018-12-21  2416.620117  7.790125 -0.020803  -5.408811  0.139071  0.223178
# 2018-12-24  2351.100098  7.762639 -0.027487  -7.146509  0.164043  0.236402
# 2018-12-25  2351.100098  7.762639  0.000000   0.000000  0.163495  0.237090
# 2018-12-26  2467.699951  7.811042  0.048403  12.584826  0.492660  0.293025
# 2018-12-27  2488.830078  7.819568  0.008526   2.216820  0.482990  0.295113
# 2018-12-28  2485.739990  7.818326 -0.001242  -0.323012  0.442585  0.279969
# 2018-12-31  2506.850098  7.826782  0.008457   2.198723  0.329049  0.283423
#
#               vol_6m    vol_1y    vol_2y
# 2018-12-18  0.153754  0.158030  0.121558
# 2018-12-19  0.155150  0.158770  0.122052
# 2018-12-20  0.156424  0.159522  0.122573
# 2018-12-21  0.158902  0.160831  0.123464
# 2018-12-24  0.162263  0.163095  0.124998
# 2018-12-25  0.162202  0.163094  0.124989
# 2018-12-26  0.176325  0.170266  0.129436
# 2018-12-27  0.176541  0.170482  0.129570
# 2018-12-28  0.176531  0.170414  0.129528
# 2018-12-31  0.176927  0.170638  0.129660

# %% [markdown]
# # Section 4: Analysis

# %%
cint = 0
cmap = ['#ff0000', '#ff7a00', '#f6ad48', '#c4c6bd', '#3193d8', '#005684']
terms = ['vol_1w', 'vol_1m', 'vol_6m', 'vol_1y', 'vol_2y']


fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111)
for term in terms:
    ax.plot(df[term], color=cmap[cint], label=term, alpha=.8)
    cint += 1


plt.xlabel('Date')
plt.ylabel('Realized Volatility')
plt.legend(loc=2, frameon=False)
ylim = ax.get_ylim()
ax = ax.twinx()
ax.grid(False)
ax.set_ylabel('Realized Volatility')
ax.set_ylim(ylim)
plt.tight_layout()
