# %% [markdown]
# # SPX Volatility Term Structure Analysis

# %% [markdown]
# Click [here](https://github.com/jackliu234/spx-vol-term-struct/blob/master/project-lab.ipynb) to download this notebook.

# %% [markdown]
# ## Section 1: Theoretical Background

# %% [markdown]
# ### Part 1

# %% [markdown]
# In this exercise we analyze the volatility structure of daily SPX return over the period 1970-2018. We used the Dupire equation to calibrate our volatility curve parameter in order to fit the realized distribution of the SPX returns over time.

# %% [markdown]
# First, we assume that the volatility follows certain form. For example we start with a linear form:
#
# $$ \sigma(r_T) = a * r_T + b $$
#
# Where $r_T=log(S_T/S_0)$ is the stock return over a fixed period $T$. We under the Black-Scholes assumption with $0$ risk-free rate, the call option premium for $S_0=1$ can be calulated as:
#
# $$ C(S_0=1, K) = \Phi(d1) - K\Phi(d2) \\
# d_{1, 2} = \dfrac{log(1/K) \pm (\sigma^2/2)T}{\sigma\sqrt{T}} $$

# %% [markdown]
# Assuming that there is a density function for $S_T$, we have:
#
# $$ C = \int^{\infty}_K(S_T-K)f_{S_T}(S_T)dS_T $$
#
# Taking partial derivative w.r.t. $K$, we get the Dupire Formula:
#
# $$ \dfrac{\partial C}{\partial K} = \int^{\infty}_K -f_{S_T}(S_T)dS_T \\
# \dfrac{\partial^2 C}{\partial K^2} = f_{S_T}(K) $$
#
# We can approximate the second-order derivative numerically:
#
# $$ f_{S_T}(K) \approx \dfrac{C(K + \triangle K) - 2C(K) + C(K - \triangle K)}{(\triangle K)^2} $$

# %% [markdown]
# ### Part 2

# %% [markdown]
# Now we define $x = log(K)$ and $\tilde{C}(x)$:
#
# $$ \tilde{C}(x) = \Phi(d1) - e^x\Phi(d2) \\
# d_{1, 2} = \dfrac{-x \pm (\sigma^2/2)T}{\sigma\sqrt{T}} $$

# %% [markdown]
# Now given any $\triangle K$, define $\triangle x$ such that:
#
# $$ \triangle x = log(K + \triangle K) - log(K) \\
# \text{therefore, } K + \triangle K = e^{x + \triangle x} \\
# \text{and } \triangle K = e^{x}(e^{\triangle x} - 1) $$
#
# We thus have equivalence between $C$ and $\tilde{C}$:
#
# $$ C(K + \triangle K) = \tilde{C}(x + \triangle x) \\
# \text{and } C(K - \triangle K) = \tilde{C}(log[e^x(2-e^{\triangle x})])$$

# %% [markdown]
# ### Part 3

# %% [markdown]
# Based on chain rule, given $r_T = log(S_T)$:
#
# $$ f_{r_T}(x) = f_{S_T}(K) \times K $$

# %% [markdown]
# Therefore:
#
# $$\begin{align} f_{r_T}(x) = f_{S_T}(K) \times K &\approx \dfrac{C(K + \triangle K) - 2C(K) + C(K - \triangle K)}{(\triangle K)^2} \times K\\
# &= \dfrac{\tilde{C}(x + \triangle x) - 2\tilde{C}(x) + \tilde{C}(log[e^x(2-e^{\triangle x})])}{[e^x(e^{\triangle x} - 1)]^2} \times e^{x}\\
# \end{align}$$

# %% [markdown]
# So finally we have:
#
# $$ f_{r_T}(x) = \dfrac{\tilde{C}(x + \triangle x) - 2\tilde{C}(x) + \tilde{C}(log[e^x(2-e^{\triangle x})])}{e^x[(e^{\triangle x} - 1)]^2} \\
# \text{where } C(x) = \Phi(\dfrac{-x + (\sigma^2/2)T}{\sigma\sqrt{T}}) - e^x\Phi(\dfrac{-x - (\sigma^2/2)T}{\sigma\sqrt{T}}) \\
# \text{and } \sigma = ax + b $$

# %% [markdown]
# So the goal of this exercise is to find the optimal parameters a, b such that $f_{r_T}(x)$ is close to the realized distribution of $r_T$.

# %% [markdown]
# $$  \text{--------------------Alternatively-------------------- }  \\
# x=ln(\frac{K}{S})\\
# K=S*e^{x}\\
# \Delta K = e^{x}\Delta x $$
#
# $$C(K\pm \Delta K)=C(e^x\pm e^x\Delta x)$$
#
# $$f_{r_T}(x) =\frac{C(e^x+ e^x\Delta x)+C(e^x- e^x\Delta x)-2C(e^x)}{(e^x\Delta x)^2}\cdot e^x$$

# %% [markdown]
# ## Section 2: Python Code

# %% [markdown]
# ### Part 1: Import Packages

# %%
import sys
import time
import json
import warnings
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from mpl_toolkits import mplot3d
from urllib.request import urlopen
from scipy.optimize import minimize
from sklearn.neighbors import KernelDensity
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Part 2: Declare Functions

# %%
def yahoo_parser(url):
    response = urlopen(url)
    data = json.loads(response.read().decode("utf-8"))['chart']['result'][0]
    t = pd.to_datetime(data['timestamp'], unit='s').date
    c = data['indicators']['quote'][0]['close']
    return pd.DataFrame({'close': c}, index=t)


def default_parser(url):
    return pd.read_csv(url, index_col=0, parse_dates=True)


def retrieve(source, code, label, column=None):
    query = {
        'yahoo': 'https://query1.finance.yahoo.com/v8/finance/chart/{}?period1=0&period2=5000000000&interval=1d',
    }
    parser = {
        'yahoo': yahoo_parser,
    }
    url = query.get(source).format(code)
    df = parser.get(source, default_parser)(url)
    df.index.name = None
    df.columns = [col.lower() for col in df.columns] if df.shape[1] > 1 else [label]
    if not column: column = df.columns
    all_dates = pd.date_range(df.index.min(), df.index.max(), freq='D')
    df = df.replace('.', None).reindex(all_dates).fillna(method='ffill')
    return df.astype('float')[column].squeeze()


def sigma_func_linear(x, a, b):
    return a * x + b


def sigma_func_quad(x, a, b, c):
    return a * x**2 + b * x + c


def calc_call_premium(x, sigma, T): 
    if sigma == 0:
        return 0
    else:
        d1 = (- x + sigma**2 / 2 * T)/(sigma * np.sqrt(T))
        d2 = (- x - sigma**2 / 2 * T)/(sigma * np.sqrt(T))
        c = norm.cdf(d1) - np.exp(x) * norm.cdf(d2)
        return c



def calc_density(x, r, T, sigma, delta_x):
    f = np.exp(r * T) * (calc_call_premium(x + delta_x, sigma, T)
                       - 2 * calc_call_premium(x, sigma, T) 
                       + calc_call_premium(np.log(np.exp(x) * (2 - np.exp(delta_x))), sigma, T)) / (np.exp(x) * (np.exp(delta_x) - 1)**2)
    return f


def calc_call_premium1(k, sigma, T): 
    #difference with the original premium calculation function lies in the input, this one takes K as input.
    
    if sigma == 0:
        return 0
    else:
        d1 = (- np.log(k) + sigma**2 / 2 * T)/(sigma * np.sqrt(T))
        d2 = (- np.log(k) - sigma**2 / 2 * T)/(sigma * np.sqrt(T))
        c = norm.cdf(d1) - k * norm.cdf(d2)
        return c



def calc_density1(x, r, T, sigma, delta_x):
    #difference with the original density function: use calc_call_premium1, delta_k=exp(x)*delta_x
    
    f = np.exp(r * T)* np.exp(x) * (calc_call_premium1( np.exp(x) + np.exp(x)*delta_x, sigma, T)
                       - 2 * calc_call_premium1(np.exp(x), sigma, T) 
                       + calc_call_premium1(np.exp(x)-np.exp(x)*delta_x, sigma, T)) / ((np.exp(x) * delta_x)**2)
    return f

'''
def calc_density_K(K, r, T, sigma, delta_K):
    f = np.exp(r * T) * (calc_call_premium(K + delta_K, sigma, T)
                       - 2 * calc_call_premium(x, sigma, T) 
                       + calc_call_premium(x - delta_x, sigma, T)) / ((np.exp(x) * (np.exp(delta_x) - 1))**2)
    return f
'''


def obj_func(params, r_series, term_day, kde, method):
    """
    :param params: one-dimension vector/list,
                    if linear, np.array([intercept, beta_1]);
                    if quad, np.array([intercept, beta_1, beta_2])
    :param r_series: pd.Series, of return / log(K/S0), of which we should calculate the prob density
    :param term_day: days to maturity of option
    :param kde: sklearn.neighbors.KernelDensity
    :param method: 'linear' / 'quad', otherwise raise Error
    
    :return: float
        Mean of Squared Errors
        Why use mean instead of sum: reduce the value of obj_func so that the solver is less sensitive
    """
    kde.fit(np.reshape(r_series.values, (-1, 1)))
    avg, std = r_series.mean(), r_series.std()
    r_sample = (np.arange(avg-3.5*std, avg+3*std, 0.05*std)).reshape(-1, 1)
    density_true = (np.exp(kde.score_samples(r_sample))).reshape(-1, 1)
    if method == 'linear' and len(params) == 2:
        density_pred = [calc_density(elem, r=0, T=term_day/260, 
                                     sigma=sigma_func_linear(elem, params[0], params[1]),
                                     delta_x=0.01) for elem in r_sample]
    elif method == 'quad' and len(params) == 3:
        density_pred = [calc_density(elem, r=0, T=term_day/260, 
                                     sigma=sigma_func_quad(elem, params[0], params[1], params[2]), 
                                     delta_x=0.01) for elem in r_sample]
    else:
        raise Exception("Wrong param dimension or fit method!")
    sse = ((density_true - density_pred) ** 2).mean()
    return sse

def obj_func1(params, r_series, term_day, kde, method):
    """
    :param params: one-dimension vector/list,
                    if linear, np.array([intercept, beta_1]);
                    if quad, np.array([intercept, beta_1, beta_2])
    :param r_series: pd.Series, of return / log(K/S0), of which we should calculate the prob density
    :param term_day: days to maturity of option
    :param kde: sklearn.neighbors.KernelDensity
    :param method: 'linear' / 'quad', otherwise raise Error
    
    :return: float
        Mean of Squared Errors
        Why use mean instead of sum: reduce the value of obj_func so that the solver is less sensitive
    """
    kde.fit(np.reshape(r_series.values, (-1, 1)))
    avg, std = r_series.mean(), r_series.std()
    r_sample = (np.arange(avg-3.5*std, avg+3*std, 0.05*std)).reshape(-1, 1)
    density_true = (np.exp(kde.score_samples(r_sample))).reshape(-1, 1)
    if method == 'linear' and len(params) == 2:
        density_pred = [calc_density1(elem, r=0, T=term_day/252, 
                                     sigma=sigma_func_linear(elem, params[0], params[1]),
                                     delta_x=0.01) for elem in r_sample]
    elif method == 'quad' and len(params) == 3:
        density_pred = [calc_density1(elem, r=0, T=term_day/252, 
                                     sigma=sigma_func_quad(elem, params[0], params[1], params[2]), 
                                     delta_x=0.01) for elem in r_sample]
    else:
        raise Exception("Wrong param dimension or fit method!")
    sse = ((density_true - density_pred) ** 2).mean()
    return sse

# %% [markdown]
# ### Part 3: Format Data

# %%
# load yahoo data
raw_df = retrieve('yahoo', '^GSPC', 'SPX').to_frame()

# %%
# remove all weekends
df = raw_df.copy()
df = df.reindex(pd.date_range(start="1970-01-02", end="2018-12-31", freq='B'))

# take the log price and return
df['log_SPX'] = np.log(df["SPX"])
df['r'] = df['log_SPX'] - df['log_SPX'].shift(1)
df['r_ann'] = df['r'] * 252

term_days = [5, 10] + list(range(20, 521, 20))
term_name = [str(i) + "D" for i in term_days]
terms = dict(zip(term_name, term_days))

# calculate rolling volatilities
for k, v in terms.items(): 
    df['mean_'+ k ] = df["r"].rolling(v).mean() * 252

# remove na
# df.fillna(value=0, inplace=True)

# %%
df.tail()
# Out:
#                     SPX   log_SPX         r      r_ann   mean_5D  mean_10D  \
# 2018-12-25  2351.100098  7.762639  0.000000   0.000000 -4.017029 -2.889814
# 2018-12-26  2467.699951  7.811042  0.048403  12.197601 -0.795530 -1.806256
# 2018-12-27  2488.830078  7.819568  0.008526   2.148610  0.435442 -1.586357
# 2018-12-28  2485.739990  7.818326 -0.001242  -0.313073  1.421304 -1.132029
# 2018-12-31  2506.850098  7.826782  0.008457   2.131070  3.232841 -0.389917
#
#             mean_20D  mean_40D  mean_60D  mean_80D    ...      mean_340D  \
# 2018-12-25 -1.659959 -0.831060 -0.915072 -0.657391    ...      -0.032911
# 2018-12-26 -1.336276 -0.594115 -0.714766 -0.496079    ...       0.000649
# 2018-12-27 -1.201308 -0.606566 -0.644503 -0.457696    ...       0.007101
# 2018-12-28 -1.319495 -0.574471 -0.626439 -0.454629    ...       0.007284
# 2018-12-31 -1.350055 -0.556378 -0.589261 -0.433964    ...       0.005561
#
# ...

# %%
np.mean(df)
# Out:
# SPX          776.934755
# log_SPX        6.116116
# r              0.000258
# r_ann          0.064951
# mean_5D        0.064612
# mean_10D       0.064738
# mean_20D       0.065904
# mean_40D       0.067050
# mean_60D       0.067430
# mean_80D       0.068025
# mean_100D      0.068818
# mean_120D      0.069473
# mean_140D      0.069940
# mean_160D      0.070212
# mean_180D      0.070307
# mean_200D      0.070300
# mean_220D      0.070355
# mean_240D      0.070395
# mean_260D      0.070392
# mean_280D      0.070296
# mean_300D      0.070140
# mean_320D      0.069971
# mean_340D      0.069779
# mean_360D      0.069583
# mean_380D      0.069453
# mean_400D      0.069344
# mean_420D      0.069279
# mean_440D      0.069186
# mean_460D      0.069102
# mean_480D      0.069066
# mean_500D      0.069056
# mean_520D      0.068982
# dtype: float64

# %% [markdown]
# ### Part 4: Data Visualization

# %% [markdown]
# Time series plot.

# %%
cmap = ['#ff0000', '#ff7a00', '#f6ad48', '#c4c6bd', '#3193d8', '#005684']

# %%
# too many windows, only display six
fig = plt.figure(figsize=(16, 32))
index = 1
for moment in ['mean']: 
    ax = fig.add_subplot(4, 1, index)
    cint = 0
    for term in terms.keys():
        ax.plot(df[moment+"_"+term], color=cmap[cint], label='rolling period = '+term, alpha=.8)
        cint += 1
        if cint==6:
            break
    plt.xlabel('Year')
    plt.ylabel('return '+moment)
    plt.legend(frameon=False, prop={'size': 12})
    plt.tight_layout()
    index += 1

# %% [markdown]
# Return distribution.

# %%
num_window = len(terms)
sns.set_style('whitegrid')
fig = plt.figure(figsize=(16, num_window*3))

index = 1
for term in terms:
    for i in ['mean_']:
        plt.subplot(num_window, 4, index)
        sns.kdeplot(df[i+term])
        index += 1

# %% [markdown]
# ### Part 5: Fitting 20D Window

# %% [markdown]
# Empirical distribution for window size 20D.

# %%
fig = plt.figure(figsize=(8, 8))
sns.kdeplot(df["mean_20D"])

# %%
# pick sample data points for fitting
avg, std = df["mean_20D"].mean(), df["mean_20D"].std()
r_sample = [round(elem, 4) for elem in np.arange(avg - 5 * std, avg + 5 * std, 0.2 * std)]
test = pd.DataFrame(r_sample, columns=['r'])

# %%
n_20D=df.mean_20D.count()
bandwidth=1.06*std*(n_20D)**(-0.2)#optimal bandwidth suggested by wiki
bandwidth
# Out:
# 0.08812520751720966

# %%
df
# Out:
#                     SPX   log_SPX         r      r_ann   mean_5D  mean_10D  \
# 1970-01-02    93.000000  4.532599       NaN        NaN       NaN       NaN
# 1970-01-05    93.459999  4.537534  0.004934   1.243377       NaN       NaN
# 1970-01-06    92.820000  4.530662 -0.006871  -1.731592       NaN       NaN
# 1970-01-07    92.629997  4.528613 -0.002049  -0.516372       NaN       NaN
# 1970-01-08    92.680000  4.529153  0.000540   0.135997       NaN       NaN
# 1970-01-09    92.400002  4.526127 -0.003026  -0.762478 -0.326214       NaN
# 1970-01-12    91.699997  4.518522 -0.007605  -1.916372 -0.958164       NaN
# 1970-01-13    91.919998  4.520919  0.002396   0.603859 -0.491073       NaN
# 1970-01-14    91.650002  4.517977 -0.002942  -0.741289 -0.536057       NaN
# 1970-01-15    91.680000  4.518304  0.000327   0.082471 -0.546762       NaN
# 1970-01-16    90.919998  4.509980 -0.008324  -2.097718 -0.813810 -0.570012
# ...

# %%
# calculate the kde density of the data points
kde = KernelDensity(bandwidth = 0.1) # larger the bandwidth, smoother the curve
kde.fit(df[['mean_20D']].dropna())
test['f_r'] = [round(elem, 4) for elem in np.exp(kde.score_samples(test[['r']]))]
test.tail()
# Out:
#          r     f_r
# 45  2.2690  0.0016
# 46  2.3792  0.0004
# 47  2.4893  0.0005
# 48  2.5995  0.0008
# 49  2.7096  0.0006

# %%
fig, ax = plt.subplots(figsize=(10,10))
bins=np.linspace(-4,3,150)
ax.hist(df.mean_20D,bins=bins)
ax1 = ax.twinx()
for kernel in ['gaussian', 'epanechnikov']:
    for b in [0.1,bandwidth]:
        kde = KernelDensity(kernel=kernel, bandwidth=b).fit(df[['mean_20D']].dropna())
        log_dens = kde.score_samples(test[['r']])
        ax1.plot(test.r, np.exp(log_dens), '-',
                label="kernel = {}, bandwidth={}".format(kernel, b))
plt.show()

# %% [markdown]
# #### Grid Search

# %%
# result = pd.DataFrame(columns=['method', 'a', 'b', 'c', 'sse'])

# %%
# start_t = time.time()
# linear_search_range = np.arange(-5, 5.1, 0.1)
# for a in linear_search_range:
#     for b in linear_search_range:
        
#         test['f_r_calc'] = list(map(lambda elem:round(calc_density(x=elem, r=0, T=20/260, sigma=sigma_func_linear(elem, a, b), delta_x=0.01), 4), test['r']))     
#         test['sse'] = round((test['f_r_calc'] - test['f_r'])**2, 4)
#         result = result.append({'method': 'linear',
#                                 'a': round(a, 4),
#                                 'b': round(b, 4),
#                                 'c': 0,
#                                 'sse': round(np.sum(test['sse']), 4)}, ignore_index=True)
# end_t = time.time()
# print("run time:", round((end_t-start_t)/60, 2), "minute")

# %%
# grid_linear_a = result.sort_values(by=['sse']).iloc[0, 1]
# grid_linear_b = result.sort_values(by=['sse']).iloc[0, 2]
# result.sort_values(by=['sse']).head()

# %%
# start_t = time.time()
# quad_search_range = np.arange(-5, 5.1, 0.5)
# for a in quad_search_range:
#     for b in quad_search_range:
#         for c in quad_search_range:

#             test['f_r_calc'] = list(map(lambda elem:round(calc_density(x=elem, r=0, T=20/260, sigma=sigma_func_quad(elem, a, b), delta_x=0.01), 4), test['r']))     
#             test['sse'] = round((test['f_r_calc'] - test['f_r'])**2, 4)
#             result = result.append({'method': 'quad',
#                                     'a': round(a, 4),
#                                     'b': round(b, 4),
#                                     'c': round(c, 4),
#                                     'sse': round(np.sum(test['sse']), 4)}, ignore_index=True)
# end_t = time.time()
# print("run time:", round((end_t-start_t)/60, 2), "minute")

# %%
# grid_quad_a = result.sort_values(by=['sse']).iloc[0, 1]
# grid_quad_b = result.sort_values(by=['sse']).iloc[0, 2]
# grid_quad_c = result.sort_values(by=['sse']).iloc[0, 3]
# result.sort_values(by=['sse']).head()

# %% [markdown]
# #### Scipy Optimization (Unbounded)

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'linear'
obj_min = minimize(obj_func, (-1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
un_linear_a, un_linear_b = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.2 minute
#      fun: 0.021670626471542116
#      jac: array([-1.06471125e-05,  2.02462543e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 56
#      nit: 14
#     njev: 14
#   status: 0
#  success: True
#        x: array([0.27163569, 1.6500445 ])

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'quad'
obj_min = minimize(obj_func, (1, -1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
un_quad_a, un_quad_b, un_quad_c = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.45 minute
#      fun: 0.005913006602926193
#      jac: array([2.65678973e-05, 5.57739404e-05, 7.75028020e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 121
#      nit: 24
#     njev: 24
#   status: 0
#  success: True
#        x: array([ 5.7211302 , -2.87617385,  1.62506394])

# %% [markdown]
# #### Scipy Optimization (Unbounded), using second approach to approximate $\Delta x$

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'linear'
obj_min = minimize(obj_func1, (-1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
un_linear_a_1, un_linear_b_1 = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.21 minute
#      fun: 0.02167067717483123
#      jac: array([5.05778007e-06, 2.58276705e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 56
#      nit: 14
#     njev: 14
#   status: 0
#  success: True
#        x: array([0.2683804 , 1.62455039])

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'quad'
obj_min = minimize(obj_func1, (1, -1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
un_quad_a_1, un_quad_b_1, un_quad_c_1 = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.47 minute
#      fun: 0.005913137787591099
#      jac: array([3.42742424e-05, 3.78419063e-05, 7.97464163e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 126
#      nit: 25
#     njev: 25
#   status: 0
#  success: True
#        x: array([ 5.64644394, -2.83924614,  1.5999648 ])

# %% [markdown]
# #### Scipy Optimization (Bounded)

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'linear'
obj_min = minimize(obj_func, (1, 1), bounds=((-5, 5), (-5, 5)), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
bd_linear_a, bd_linear_b = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.21 minute
#      fun: 0.02167065480869362
#      jac: array([3.00470274e-05, 4.99009620e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 56
#      nit: 14
#     njev: 14
#   status: 0
#  success: True
#        x: array([0.27381086, 1.65041932])

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'quad'
obj_min = minimize(obj_func, (1, -1, 1), bounds=((-5, 5), (-5, 5), (-5, 5)), 
                   args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
bd_quad_a, bd_quad_b, bd_quad_c = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.39 minute
#      fun: 0.006119925080556581
#      jac: array([-0.00057987,  0.00011929,  0.00030595])
#  message: 'Optimization terminated successfully.'
#     nfev: 107
#      nit: 21
#     njev: 21
#   status: 0
#  success: True
#        x: array([ 5.        , -2.70519146,  1.6525893 ])

# %% [markdown]
# #### Scipy Optimization (Bounded), using second approach to approximate $\Delta x$

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'linear'
obj_min = minimize(obj_func1, (1, 1), bounds=((-5, 5), (-5, 5)), args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
bd_linear_a_1, bd_linear_b_1 = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.2 minute
#      fun: 0.021670690185551855
#      jac: array([1.54846348e-05, 4.27742489e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 56
#      nit: 14
#     njev: 14
#   status: 0
#  success: True
#        x: array([0.2688683 , 1.62477956])

# %%
start_t = time.time()
r_series = df['mean_20D'].dropna()
term_day = 20
kde = KernelDensity(bandwidth=0.1)
method = 'quad'
obj_min = minimize(obj_func1, (1, -1, 1), bounds=((-5, 5), (-5, 5), (-5, 5)), 
                   args=(r_series, term_day, kde, method), method='SLSQP')
end_t = time.time()
bd_quad_a_1, bd_quad_b_1, bd_quad_c_1 = obj_min.x
print("run time:", round((end_t-start_t)/60, 2), "minute")
obj_min
# Out:
# run time: 0.45 minute
#      fun: 0.006074116533534145
#      jac: array([-5.37591637e-04,  1.58927287e-05,  1.20894867e-04])
#  message: 'Optimization terminated successfully.'
#     nfev: 121
#      nit: 24
#     njev: 24
#   status: 0
#  success: True
#        x: array([ 5.        , -2.69228864,  1.62541308])

# %% [markdown]
# ### Part 6: Fitting Result

# %% [markdown]
# #### Grid Search Results

# %%
# test['f_r_grid_linear_fit'] = [round(calc_density(x=elem, r=0, T=20/260, sigma=sigma_func_linear(elem, grid_linear_a, grid_linear_b), delta_x=0.01), 4) for elem in test['r']]
# test['f_r_grid_quad_fit'] = [round(calc_density(x=elem, r=0, T=20/260, sigma=sigma_func_quad(elem, grid_quad_a, grid_quad_b, grid_quad_c), delta_x=0.01), 4) for elem in test['r']]

# fig = plt.figure(figsize=(8, 8))
# plt.plot(test['r'], test['f_r'])
# plt.plot(test['r'], test['f_r_grid_linear_fit'])
# plt.plot(test['r'], test['f_r_grid_quad_fit'])
# plt.legend()

# %%
# test['vol_grid_linear_fit'] = [sigma_func_linear(elem, grid_linear_a, grid_linear_b) for elem in test['r']]
# test['vol_grid_quad_fit'] = [sigma_func_quad(elem, grid_quad_a, grid_quad_b, grid_quad_c) for elem in test['r']]

# plt.plot(test['r'], test['vol_grid_linear_fit'])
# plt.plot(test['r'], test['vol_grid_quad_fit'])
# plt.legend()
# plt.xlabel('return')
# plt.ylabel('volatility')

# %% [markdown]
# #### Scipy Optimization (Unbounded) Result

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 8),sharey=True)

test['f_r_un_linear_fit'] = [round(calc_density(x=elem, r=0, T=20/252, sigma=sigma_func_linear(elem, un_linear_a, un_linear_b), delta_x=0.01), 4) for elem in test['r']]
test['f_r_un_quad_fit'] = [round(calc_density(x=elem, r=0, T=20/252, sigma=sigma_func_quad(elem, un_quad_a, un_quad_b, un_quad_c), delta_x=0.01), 4) for elem in test['r']]

ax1.plot(test['r'], test['f_r'])
ax1.plot(test['r'], test['f_r_un_linear_fit'])
ax1.plot(test['r'], test['f_r_un_quad_fit'])
ax1.legend()
ax1.set_title('Approach 1')

test['f_r_un_linear_fit_1'] = [round(calc_density1(x=elem, r=0, T=20/252, sigma=sigma_func_linear(elem, un_linear_a_1, un_linear_b_1), delta_x=0.01), 4) for elem in test['r']]
test['f_r_un_quad_fit_1'] = [round(calc_density1(x=elem, r=0, T=20/252, sigma=sigma_func_quad(elem, un_quad_a_1, un_quad_b_1, un_quad_c_1), delta_x=0.01), 4) for elem in test['r']]

ax2.plot(test['r'], test['f_r'])
ax2.plot(test['r'], test['f_r_un_linear_fit_1'],label='f_r_un_linear_fit')
ax2.plot(test['r'], test['f_r_un_quad_fit_1'],label='f_r_un_quad_fit')
ax2.set_title('Approach 2')
ax2.legend()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(16, 6),sharey=True)


test['vol_un_linear_fit'] = [sigma_func_linear(elem, un_linear_a, un_linear_b) for elem in test['r']]
test['vol_un_quad_fit'] = [sigma_func_quad(elem, un_quad_a, un_quad_b, un_quad_c) for elem in test['r']]

ax1.plot(test['r'], test['vol_un_linear_fit'])
ax1.plot(test['r'], test['vol_un_quad_fit'])
ax1.legend()
ax1.set_xlabel('return')
ax1.set_ylabel('volatility')
ax1.set_title('Approach 1')

test['vol_un_linear_fit_1'] = [sigma_func_linear(elem, un_linear_a_1, un_linear_b_1) for elem in test['r']]
test['vol_un_quad_fit_1'] = [sigma_func_quad(elem, un_quad_a_1, un_quad_b_1, un_quad_c_1) for elem in test['r']]

ax2.plot(test['r'], test['vol_un_linear_fit_1'],label='vol_un_linear_fit')
ax2.plot(test['r'], test['vol_un_quad_fit_1'],label='vol_un_quad_fit')
ax2.legend()
ax2.set_xlabel('return')
ax2.set_ylabel('volatility')
ax2.set_title('Approach 2')
# Out:
# Text(0.5, 1.0, 'Approach 2')

# %% [markdown]
# #### Scipy Optimization (Bonuded) Result

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 8),sharey=True)

test['f_r_bd_linear_fit'] = [round(calc_density(x=elem, r=0, T=20/252, sigma=sigma_func_linear(elem, bd_linear_a, bd_linear_b), delta_x=0.01), 4) for elem in test['r']]
test['f_r_bd_quad_fit'] = [round(calc_density(x=elem, r=0, T=20/252, sigma=sigma_func_quad(elem, bd_quad_a, bd_quad_b, bd_quad_c), delta_x=0.01), 4) for elem in test['r']]

fig = plt.figure(figsize=(8, 8))
ax1.plot(test['r'], test['f_r'])
ax1.plot(test['r'], test['f_r_bd_linear_fit'])
ax1.plot(test['r'], test['f_r_bd_quad_fit'])
ax1.set_title('Approach 1')
ax1.legend()

test['f_r_bd_linear_fit_1'] = [round(calc_density1(x=elem, r=0, T=20/252, sigma=sigma_func_linear(elem, bd_linear_a_1, bd_linear_b_1), delta_x=0.01), 4) for elem in test['r']]
test['f_r_bd_quad_fit_1'] = [round(calc_density1(x=elem, r=0, T=20/252, sigma=sigma_func_quad(elem, bd_quad_a_1, bd_quad_b_1, bd_quad_c_1), delta_x=0.01), 4) for elem in test['r']]

fig = plt.figure(figsize=(8, 8))
ax2.plot(test['r'], test['f_r'])
ax2.plot(test['r'], test['f_r_bd_linear_fit_1'],label='f_r_bd_linear_fit')
ax2.plot(test['r'], test['f_r_bd_quad_fit_1'],label='f_r_bd_quad_fit')
ax2.set_title('Approach 2')
ax2.legend()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 8),sharey=True)

test['vol_bd_linear_fit'] = [sigma_func_linear(elem, bd_linear_a, bd_linear_b) for elem in test['r']]
test['vol_bd_quad_fit'] = [sigma_func_quad(elem, bd_quad_a, bd_quad_b, bd_quad_c) for elem in test['r']]

ax1.plot(test['r'], test['vol_bd_linear_fit'])
ax1.plot(test['r'], test['vol_bd_quad_fit'])
ax1.legend()
ax1.set_xlabel('return')
ax1.set_ylabel('volatility')
ax1.set_title('Approach 1')

test['vol_bd_linear_fit_1'] = [sigma_func_linear(elem, bd_linear_a_1, bd_linear_b_1) for elem in test['r']]
test['vol_bd_quad_fit_1'] = [sigma_func_quad(elem, bd_quad_a_1, bd_quad_b_1, bd_quad_c_1) for elem in test['r']]

ax2.plot(test['r'], test['vol_bd_linear_fit_1'],label='vol_bd_linear_fit')
ax2.plot(test['r'], test['vol_bd_quad_fit_1'],label='vol_bd_quad_fit')
ax2.legend()
ax2.set_xlabel('return')
# ax2.set_ylabel('volatility')
ax2.set_title('Approach 2')
# Out:
# Text(0.5, 1.0, 'Approach 2')

# %% [markdown]
# ### Part 7: Construct Term Curve

# %% [markdown]
# Base on performance above, we chose to use the **unbounded scipy optimization** with **quadratic volatility function** to construct the volatility term curve.

# %%
curve = pd.DataFrame(columns=['term', 'a', 'b', 'c'])
for k, v in terms.items(): 
    r_series = df['mean_' + k].dropna()
    term_day = v
    kde = KernelDensity(bandwidth=0.1)
    method = 'quad'
    obj_min = minimize(obj_func, (1, -1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
    curve_un_quad_a, curve_un_quad_b, curve_un_quad_c = obj_min.x
    test['vol_un_quad_fit_' + k] = [sigma_func_quad(elem, curve_un_quad_a, curve_un_quad_b, curve_un_quad_c) for elem in test['r']]
    curve = curve.append({'term': v,
                          'a': round(curve_un_quad_a, 4),
                          'b': round(curve_un_quad_b, 4),
                          'c': round(curve_un_quad_c, 4)}, ignore_index=True)
#     plt.plot(test['r'], test['vol_un_quad_fit_' + k])
#
# plt.legend()

# %%
def f(x, y):
    z = []
    for k, v in terms.items():
        for i in range(len(test['r'])):
            z.append(test['vol_un_quad_fit_' + k][i])
    return np.array(z)

x = test['r']
y = term_days
X, Y = np.meshgrid(x, y)
Z = f(X, Y).reshape(X.shape)


fig = plt.figure(figsize=(16, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('ITM: Log ITM')
ax.set_ylabel('Term: Business Days')
ax.set_zlabel('Volatility');

# %%
curve_1 = pd.DataFrame(columns=['term', 'a', 'b', 'c'])

for k, v in terms.items(): 
    r_series = df['mean_' + k].dropna()
    term_day = v
    kde = KernelDensity(bandwidth=0.1)
    method = 'quad'
    obj_min = minimize(obj_func1, (1, -1, 1), args=(r_series, term_day, kde, method), method='SLSQP')
    curve_un_quad_a, curve_un_quad_b, curve_un_quad_c = obj_min.x
    test['vol_un_quad_fit_1_' + k] = [sigma_func_quad(elem, curve_un_quad_a, curve_un_quad_b, curve_un_quad_c) for elem in test['r']]
    curve_1 = curve_1.append({'term': v,
                          'a': round(curve_un_quad_a, 4),
                          'b': round(curve_un_quad_b, 4),
                          'c': round(curve_un_quad_c, 4)}, ignore_index=True)
#     plt.plot(test['r'], test['vol_un_quad_fit_1_' + k])

# plt.legend()

# %%
def f1(x, y):
    z = []
    for k, v in terms.items():
        for i in range(len(test['r'])):
            z.append(test['vol_un_quad_fit_1_' + k][i])
    return np.array(z)

x = test['r']
y = term_days
X, Y = np.meshgrid(x, y)
Z_1 = f1(X, Y).reshape(X.shape)


fig = plt.figure(figsize=(16, 12))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z_1, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('ITM: Log ITM')
ax.set_ylabel('Term: Business Days')
ax.set_zlabel('Volatility');

# %%
curve.index=curve.term
curve.drop(columns=['term'],inplace=True)
curve_1.index=curve_1.term
curve_1.drop(columns=['term'],inplace=True)
curve_1.columns=['a_1','b_1','c_1']
curve_2 = pd.concat([curve, curve_1], axis=1, sort=False)

# %%
fig, (ax1,ax2,ax3)=plt.subplots(3,1,figsize=(7,20),sharex=True)
ax1.plot(curve.index,curve.a,label='a from approach 1')
ax1.plot(curve.index,curve_2.a_1,label='a from approach 2')
ax1.legend()
ax1.set_xlabel('Term')

ax2.plot(curve.index,curve.b,label='b from approach 1')
ax2.plot(curve.index,curve_2.b_1,label='b from approach 2')
ax2.legend()
ax2.set_xlabel('Term')

ax3.plot(curve.index,curve.c,label='c from approach 1')
ax3.plot(curve.index,curve_2.c_1,label='c from approach 2')
ax3.legend()
ax3.set_xlabel('Term')
# Out:
# Text(0.5, 0, 'Term')
